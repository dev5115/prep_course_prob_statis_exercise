# %%
# import numpy
import numpy as np

# import matplotlib.pyplot
import matplotlib.pyplot as plt

# import Counter
from collections import Counter

# use style 'fivethirtyeight' (optional)
plt.style.use('fivethirtyeight')

# %% [markdown]
# #### Create function `perform_bernouli_trial` with parameters n and p
#
# PARAMS:
# - n (int) - number of trials
# - p (float) - probability of success
#
# RETURNS:
# - n_success (int) - number of successes

# %%
def perform_bernouli_trial(n,p):
    n_success=np.random.binomial(n,p)
    return n_success

# %% [markdown]
# #### Use function `perform_bernoulli_trials` with inputs n = 100, p = 0.5

# %%
perform_bernouli_trial(100,0.5)
# Out:
# 56

# %% [markdown]
# #### Call function _perform_bernoulli_trials_ 1000-times with same parameters as before and store the result in `successes_list`

# %%
successes_list=[]
size=1000
for i in range(size):
    successes_list.append(perform_bernouli_trial(100,0.5))
successes_list
# Out:
# [48,
#  55,
#  52,
#  52,
#  47,
#  45,
#  48,
#  59,
#  52,
#  55,
#  44,
#  49,
#  54,
#  50,
#  42,
#  42,
#  54,
#  49,
#  48,
#  56,
#  46,
#  51,
#  50,
#  57,
#  40,
#  47,
#  49,
#  46,
#  46,
#  42,
#  43,
#  50,
#  44,
#  55,
#  44,
#  48,
#  58,
#  56,
#  46,
#  46,
#  40,
#  54,
#  52,
#  60,
#  51,
#  55,
#  44,
#  52,
#  45,
#  47,
#  65,
#  44,
#  47,
#  52,
#  46,
#  50,
#  44,
#  45,
#  50,
#  44,
#  51,
#  59,
#  56,
#  54,
#  59,
#  49,
#  53,
#  58,
#  53,
#  66,
#  50,
#  57,
#  43,
#  50,
#  53,
#  53,
#  52,
#  49,
#  39,
#  52,
#  48,
#  48,
#  59,
#  56,
#  51,
#  46,
#  51,
#  54,
#  53,
#  55,
#  48,
#  50,
#  51,
#  40,
#  37,
#  43,
#  47,
#  54,
#  54,
#  46,
#  46,
#  44,
#  44,
#  51,
#  42,
#  47,
#  52,
#  51,
#  47,
#  52,
#  53,
#  47,
#  51,
#  50,
#  54,
#  53,
#  52,
#  47,
#  55,
#  39,
#  54,
#  53,
#  56,
#  53,
#  48,
#  55,
#  42,
#  45,
#  47,
#  47,
#  50,
#  53,
#  50,
#  59,
#  55,
#  46,
#  49,
#  54,
#  49,
#  52,
#  49,
#  51,
#  45,
#  47,
#  48,
#  48,
#  55,
#  47,
#  51,
#  45,
#  52,
#  50,
#  42,
#  52,
#  44,
#  52,
#  44,
#  50,
#  55,
#  44,
#  51,
#  45,
#  48,
#  49,
#  56,
#  51,
#  48,
#  47,
#  52,
#  49,
#  41,
#  46,
#  53,
#  53,
#  51,
#  54,
#  47,
#  51,
#  43,
#  49,
#  47,
#  42,
#  46,
#  55,
#  54,
#  47,
#  49,
#  49,
#  48,
#  52,
#  48,
#  50,
#  53,
#  49,
#  49,
#  47,
#  46,
#  44,
#  52,
#  44,
#  48,
#  52,
#  39,
#  42,
#  54,
#  48,
#  48,
#  51,
#  44,
#  58,
#  51,
#  60,
#  47,
#  44,
#  56,
#  50,
#  53,
#  57,
#  49,
#  53,
#  48,
#  45,
#  49,
#  46,
#  53,
#  38,
#  49,
#  59,
#  56,
#  48,
#  52,
#  39,
#  46,
#  47,
#  56,
#  57,
#  49,
#  55,
#  44,
#  45,
#  50,
#  48,
#  48,
#  49,
#  34,
#  40,
#  51,
#  47,
#  50,
#  46,
#  49,
#  47,
#  42,
#  49,
#  47,
#  54,
#  47,
#  52,
#  51,
#  54,
#  46,
#  47,
#  48,
#  52,
#  52,
#  52,
#  58,
#  54,
#  53,
#  43,
#  38,
#  58,
#  41,
#  48,
#  49,
#  54,
#  54,
#  55,
#  52,
#  45,
#  55,
#  47,
#  53,
#  60,
#  49,
#  54,
#  43,
#  53,
#  40,
#  57,
#  45,
#  51,
#  54,
#  44,
#  57,
#  49,
#  51,
#  52,
#  42,
#  41,
#  45,
#  53,
#  42,
#  46,
#  57,
#  54,
#  52,
#  48,
#  47,
#  54,
#  54,
#  51,
#  57,
#  46,
#  49,
#  47,
#  54,
#  48,
#  53,
#  51,
#  55,
#  49,
#  52,
#  53,
#  55,
#  51,
#  42,
#  51,
#  50,
#  57,
#  49,
#  43,
#  52,
#  57,
#  56,
#  45,
#  45,
#  45,
#  49,
#  45,
#  53,
#  48,
#  54,
#  48,
#  57,
#  55,
#  51,
#  50,
#  47,
#  54,
#  50,
#  49,
#  52,
#  43,
#  55,
#  48,
#  44,
#  51,
#  52,
#  49,
#  49,
#  55,
#  44,
#  49,
#  47,
#  54,
#  53,
#  48,
#  46,
#  55,
#  49,
#  49,
#  52,
#  46,
#  51,
#  49,
#  55,
#  54,
#  53,
#  54,
#  58,
#  46,
#  46,
#  61,
#  56,
#  42,
#  50,
#  46,
#  50,
#  52,
#  54,
#  46,
#  44,
#  53,
#  47,
#  50,
#  51,
#  61,
#  45,
#  49,
#  54,
#  59,
#  42,
#  47,
#  54,
#  57,
#  61,
#  56,
#  51,
#  50,
#  55,
#  46,
#  45,
#  56,
#  55,
#  49,
#  59,
#  45,
#  40,
#  53,
#  50,
#  52,
#  49,
#  42,
#  44,
#  49,
#  48,
#  55,
#  45,
#  49,
#  51,
#  36,
#  55,
#  53,
#  49,
#  54,
#  50,
#  43,
#  51,
#  49,
#  50,
#  52,
#  48,
#  49,
#  46,
#  53,
#  51,
#  49,
#  42,
#  51,
#  47,
#  53,
#  43,
#  51,
#  44,
#  53,
#  53,
#  41,
#  38,
#  51,
#  54,
#  58,
#  41,
#  50,
#  43,
#  46,
#  42,
#  48,
#  47,
#  46,
#  52,
#  45,
#  50,
#  49,
#  42,
#  59,
#  58,
#  59,
#  60,
#  59,
#  52,
#  51,
#  53,
#  46,
#  43,
#  48,
#  49,
#  53,
#  57,
#  49,
#  58,
#  43,
#  57,
#  51,
#  52,
#  53,
#  51,
#  53,
#  55,
#  55,
#  50,
#  40,
#  51,
#  45,
#  53,
#  49,
#  57,
#  52,
#  56,
#  40,
#  46,
#  51,
#  52,
#  51,
#  51,
#  50,
#  49,
#  48,
#  46,
#  56,
#  43,
#  55,
#  41,
#  46,
#  48,
#  56,
#  54,
#  49,
#  51,
#  50,
#  48,
#  55,
#  43,
#  63,
#  52,
#  48,
#  54,
#  47,
#  52,
#  47,
#  58,
#  59,
#  48,
#  56,
#  58,
#  47,
#  41,
#  50,
#  48,
#  52,
#  53,
#  44,
#  45,
#  52,
#  51,
#  43,
#  47,
#  53,
#  45,
#  49,
#  49,
#  47,
#  46,
#  47,
#  54,
#  57,
#  52,
#  49,
#  51,
#  51,
#  53,
#  48,
#  50,
#  45,
#  50,
#  53,
#  55,
#  43,
#  57,
#  52,
#  55,
#  50,
#  46,
#  52,
#  45,
#  46,
#  51,
#  57,
#  61,
#  55,
#  58,
#  61,
#  50,
#  56,
#  53,
#  51,
#  43,
#  49,
#  48,
#  46,
#  52,
#  46,
#  44,
#  45,
#  57,
#  55,
#  52,
#  57,
#  56,
#  41,
#  44,
#  44,
#  38,
#  52,
#  45,
#  46,
#  46,
#  47,
#  51,
#  45,
#  51,
#  54,
#  44,
#  49,
#  49,
#  46,
#  54,
#  54,
#  52,
#  54,
#  51,
#  54,
#  45,
#  52,
#  40,
#  49,
#  51,
#  44,
#  51,
#  52,
#  50,
#  45,
#  45,
#  49,
#  55,
#  50,
#  52,
#  50,
#  50,
#  48,
#  44,
#  52,
#  49,
#  46,
#  46,
#  49,
#  45,
#  46,
#  54,
#  54,
#  46,
#  50,
#  51,
#  47,
#  52,
#  56,
#  54,
#  41,
#  47,
#  41,
#  48,
#  47,
#  44,
#  39,
#  53,
#  60,
#  34,
#  60,
#  50,
#  58,
#  48,
#  50,
#  50,
#  47,
#  51,
#  49,
#  46,
#  40,
#  48,
#  50,
#  55,
#  57,
#  54,
#  42,
#  52,
#  44,
#  55,
#  49,
#  51,
#  58,
#  56,
#  51,
#  51,
#  50,
#  53,
#  55,
#  50,
#  49,
#  49,
#  41,
#  49,
#  51,
#  48,
#  45,
#  42,
#  45,
#  44,
#  55,
#  52,
#  47,
#  44,
#  39,
#  48,
#  50,
#  57,
#  55,
#  51,
#  56,
#  57,
#  48,
#  54,
#  35,
#  46,
#  47,
#  41,
#  54,
#  54,
#  48,
#  44,
#  52,
#  52,
#  45,
#  46,
#  49,
#  51,
#  50,
#  43,
#  45,
#  52,
#  51,
#  50,
#  56,
#  60,
#  50,
#  44,
#  61,
#  48,
#  49,
#  46,
#  44,
#  55,
#  51,
#  48,
#  53,
#  53,
#  57,
#  47,
#  42,
#  53,
#  44,
#  43,
#  52,
#  49,
#  57,
#  49,
#  56,
#  47,
#  55,
#  48,
#  45,
#  45,
#  51,
#  54,
#  49,
#  56,
#  49,
#  50,
#  49,
#  49,
#  51,
#  46,
#  51,
#  49,
#  49,
#  51,
#  51,
#  51,
#  49,
#  51,
#  46,
#  55,
#  46,
#  51,
#  48,
#  56,
#  56,
#  44,
#  47,
#  47,
#  51,
#  51,
#  40,
#  54,
#  54,
#  49,
#  49,
#  56,
#  45,
#  50,
#  53,
#  52,
#  54,
#  49,
#  52,
#  40,
#  49,
#  45,
#  49,
#  57,
#  48,
#  55,
#  47,
#  49,
#  43,
#  54,
#  58,
#  51,
#  59,
#  47,
#  45,
#  53,
#  59,
#  40,
#  44,
#  48,
#  48,
#  59,
#  50,
#  52,
#  44,
#  47,
#  56,
#  51,
#  49,
#  38,
#  43,
#  49,
#  55,
#  55,
#  56,
#  55,
#  47,
#  52,
#  58,
#  46,
#  51,
#  55,
#  44,
#  53,
#  46,
#  55,
#  41,
#  45,
#  53,
#  53,
#  54,
#  53,
#  44,
#  49,
#  50,
#  53,
#  50,
#  44,
#  44,
#  34,
#  46,
#  43,
#  46,
#  53,
#  56,
#  55,
#  35,
#  53,
#  46,
#  55,
#  48,
#  61,
#  47,
#  47,
#  52,
#  58,
#  54,
#  50,
#  54,
#  46,
#  51,
#  41,
#  53,
#  47,
#  47,
#  45,
#  48,
#  64,
#  50,
#  43,
#  44,
#  52,
#  46,
#  57,
#  55,
#  45,
#  53,
#  55,
#  44,
#  45,
#  49,
#  54,
#  48,
#  56,
#  54,
#  44,
#  49,
#  53,
#  46,
#  44,
#  56,
#  48,
#  50,
#  53,
#  57,
#  51,
#  50,
#  47,
#  49,
#  52,
#  54,
#  47,
#  56,
#  48,
#  53,
#  49,
#  54,
#  54,
#  49,
#  64,
#  45,
#  43,
#  52,
#  62,
#  47,
#  54,
#  51,
#  44,
#  46,
#  50,
#  44,
#  44,
#  52,
#  39,
#  52,
#  50,
#  51,
#  49,
#  57,
#  38,
#  45,
#  54,
#  48,
#  55,
#  61,
#  46,
#  48,
#  58,
#  52,
#  43,
#  44,
#  58,
#  59,
#  44,
#  42,
#  45,
#  51,
#  45,
#  56,
#  49,
#  45,
#  47,
#  57,
#  41,
#  43]

# %% [markdown]
# #### Count occurence of each number from `successes_list` using Counter and store the result in `count_occurence`
#
# You can find for more info about Counter [**here**](https://docs.python.org/2/library/collections.html#collections.Counter).

# %%
count_occurence=Counter(successes_list)
count_occurence
# Out:
# Counter({48: 63,
#          55: 53,
#          52: 73,
#          47: 63,
#          45: 51,
#          59: 16,
#          44: 54,
#          49: 93,
#          54: 64,
#          50: 63,
#          42: 22,
#          56: 35,
#          46: 62,
#          51: 82,
#          57: 30,
#          40: 13,
#          43: 27,
#          58: 19,
#          60: 7,
#          65: 1,
#          53: 61,
#          66: 1,
#          39: 7,
#          37: 1,
#          41: 15,
#          38: 6,
#          34: 3,
#          61: 8,
#          36: 1,
#          63: 1,
#          35: 2,
#          64: 2,
#          62: 1})

# %% [markdown]
# #### Count the probability for each number from `count_occurence` and store the result in `probas`

# %%
probas=[val/size for val in count_occurence.values()]
probas
# Out:
# [0.063,
#  0.053,
#  0.073,
#  0.063,
#  0.051,
#  0.016,
#  0.054,
#  0.093,
#  0.064,
#  0.063,
#  0.022,
#  0.035,
#  0.062,
#  0.082,
#  0.03,
#  0.013,
#  0.027,
#  0.019,
#  0.007,
#  0.001,
#  0.061,
#  0.001,
#  0.007,
#  0.001,
#  0.015,
#  0.006,
#  0.003,
#  0.008,
#  0.001,
#  0.001,
#  0.002,
#  0.002,
#  0.001]

# %% [markdown]
# Below you have some information about how to do plots in Python. We will be covering all of this during the bootcamp. But you can find these basics here so we can visualize the distributions.

# %%
# plot distribution (PMF) of 'succes_list'
plt.scatter(x=count_occurence.keys(), y=probas)
plt.xlabel('number of succeess out of 100')
plt.ylabel('probability')
# Show the plot
plt.show()

# %% [markdown]
# #### Generate 100000 numbers from uniform distribution with parameters a = 1, b = 6

# %%
samples_uniform=np.random.uniform(1, 6, size=100000)

# %%
samples_uniform
# Out:
# array([4.71755212, 3.11378924, 1.78251532, ..., 4.11503438, 5.70445711,
#        5.14840268])

# %% [markdown]
# #### Check the mean of uniform data (using NumPy)

# %%
mean_uniform=np.mean(samples_uniform)
mean_uniform
# Out:
# 3.4960544356768373

# %% [markdown]
# #### Generate 100000 numbers from exponential distribution with parameter beta = 0.5

# %%
samples_exp=np.random.exponential(0.5,size=100000)
samples_exp
# Out:
# array([0.67402616, 0.00317248, 1.4757422 , ..., 0.13435127, 0.14691861,
#        0.46291219])

# %% [markdown]
# #### Plot histogram of exponential distribution with params `density=True`, `bins=100`

# %%
plt.hist(samples_exp,density=True,histtype='step' ,bins=100)
plt.show()

# %% [markdown]
# #### Check the mean of exponential data

# %%
mean_exp=np.mean(samples_exp)
mean_exp
# Out:
# 0.4989458323280839
